-- %%
select * from movie_gross
where (genre = 'Adventure' or genre = 'Musical') and mpaa_rating = 'G' and  inflation_adjusted_gross > 100e6

select * from movie_gross
where genre not in ('Adventure','Musical','Comedy') and mpaa_rating = 'G' and  inflation_adjusted_gross > 100e6

select movie_title,COUNT(movie_title) as [count],AVG(total_gross) as [AVG] 
from movie_gross GROUP BY movie_title
-- Out:
-- (30 rows affected)
-- (4 rows affected)
-- (573 rows affected)
-- Total execution time: 00:00:00.077
-- ...

-- %%
SELECT * from movie_gross 
where inflation_adjusted_gross not 0BETWEEN 500e6 and 1000e6
-- Out:
-- : Msg 102, Level 15, State 1, Line 2
-- Incorrect syntax near '0'.
-- Total execution time: 00:00:00.006

-- %%
select top 5 movie_title,inflation_adjusted_gross,inflation_adjusted_gross * 31 as [Thai_bath]
 from movie_gross group by movie_title,inflation_adjusted_gross

 select top 5 movie_title,inflation_adjusted_gross,inflation_adjusted_gross * 31 as [Thai_bath]
 from movie_gross
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>movie_title</th><th>inflation_adjusted_gross</th><th>Thai_bath</th></tr><tr><td>Snow White and the Seven Dwarfs</td><td>5228953251</td><td>162097550781</td></tr><tr><td>Pinocchio</td><td>2188229052</td><td>67835100612</td></tr><tr><td>Fantasia</td><td>2187090808</td><td>67799815048</td></tr><tr><td>Song of the South</td><td>1078510579</td><td>33433827949</td></tr><tr><td>Cinderella</td><td>920608730</td><td>28538870630</td></tr></table>
-- <table><tr><th>movie_title</th><th>inflation_adjusted_gross</th><th>Thai_bath</th></tr><tr><td>Snow White and the Seven Dwarfs</td><td>5228953251</td><td>162097550781</td></tr><tr><td>Pinocchio</td><td>2188229052</td><td>67835100612</td></tr><tr><td>Fantasia</td><td>2187090808</td><td>67799815048</td></tr><tr><td>Song of the South</td><td>1078510579</td><td>33433827949</td></tr><tr><td>Cinderella</td><td>920608730</td><td>28538870630</td></tr></table>

-- %%
select top 10 YEAR, studio_entertainment+disney_consumer_products+disney_interactive
+ walt_disney_parks_and_resorts + disney_media_networks as [total revenue] , total  FROM revenue
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.001
-- <table><tr><th>YEAR</th><th>total revenue</th><th>total</th></tr><tr><td>1991</td><td>NULL</td><td>6111</td></tr><tr><td>1992</td><td>NULL</td><td>7502</td></tr><tr><td>1993</td><td>NULL</td><td>8529</td></tr><tr><td>1994</td><td>NULL</td><td>10414</td></tr><tr><td>1995</td><td>NULL</td><td>12525</td></tr><tr><td>1996</td><td>NULL</td><td>18739</td></tr><tr><td>1997</td><td>22473</td><td>22473</td></tr><tr><td>1998</td><td>22976</td><td>22976</td></tr><tr><td>1999</td><td>23402</td><td>23402</td></tr><tr><td>2000</td><td>25382</td><td>25402</td></tr></table>

-- %%
select top 10 YEAR,
isnull(studio_entertainment,0)+
isnull(disney_consumer_products,0)+
isnull(disney_interactive,0)+ 
isnull(walt_disney_parks_and_resorts,0) + 
isnull(disney_media_networks,0) as [total revenue] ,
  total  FROM revenue
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.003
-- <table><tr><th>YEAR</th><th>total revenue</th><th>total</th></tr><tr><td>1991</td><td>6111</td><td>6111</td></tr><tr><td>1992</td><td>7502</td><td>7502</td></tr><tr><td>1993</td><td>8529.2</td><td>8529</td></tr><tr><td>1994</td><td>10413.8</td><td>10414</td></tr><tr><td>1995</td><td>12525.3</td><td>12525</td></tr><tr><td>1996</td><td>8644</td><td>18739</td></tr><tr><td>1997</td><td>22473</td><td>22473</td></tr><tr><td>1998</td><td>22976</td><td>22976</td></tr><tr><td>1999</td><td>23402</td><td>23402</td></tr><tr><td>2000</td><td>25382</td><td>25402</td></tr></table>

-- %%
select sum(disney_media_networks), COUNT(*),count(disney_media_networks) from revenue
-- Out:
-- ...
-- (1 row affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>(No column name)</th><th>(No column name)</th><th>(No column name)</th></tr><tr><td>296187</td><td>26</td><td>23</td></tr></table>

-- %%
select * from movie_gross WHERE movie_title LIKE 'be%'

select * from movie_gross WHERE movie_title LIKE '[byw]%' order by movie_title

select * from movie_gross WHERE movie_title LIKE '[a-f]%'

select * from movie_gross WHERE movie_title LIKE '__n%'

select * from movie_gross WHERE movie_title LIKE '___[nmxpy]%'
-- Out:
-- (11 rows affected)
-- (57 rows affected)
-- (167 rows affected)
-- (56 rows affected)
-- (75 rows affected)
-- Total execution time: 00:00:00.018
-- ...

-- %%
select top 10 * from movie_gross

SELECT top 10 * from movie_gross order by inflation_adjusted_gross DESC
-- Out:
-- (10 rows affected)
-- (10 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %%
select * FROM movie_gross 
order by genre,inflation_adjusted_gross desc
-- Out:
-- (579 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %%
select top 3 * ,newid() from movie_gross 
order by NEWID()

select top 1 percent * FROM movie_gross
order by NEWID()

select top 70 percent * , NEWID() FROM movie_gross order by NEWID()

drop table if exists train_data
select top 70 percent * into train_data from movie_gross ORDER by NEWID()
-- Out:
-- (3 rows affected)
-- (6 rows affected)
-- (406 rows affected)
-- (406 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>movie_title</th><th>release_date</th><th>genre</th><th>mpaa_rating</th><th>total_gross</th><th>inflation_adjusted_gross</th><th>(No column name)</th></tr><tr><td>The Greatest Game Ever Played</td><td>2005-09-30</td><td>Drama</td><td>PG</td><td>15331289</td><td>20162672</td><td>06275524-30fa-41e2-82bb-005e62c8a68e</td></tr><tr><td>Another Stakeout</td><td>1993-07-23</td><td>Comedy</td><td>PG-13</td><td>20107504</td><td>40943541</td><td>46d6b87e-6a6d-4b87-af09-010713c0576a</td></tr><tr><td>The Hand That Rocks the Cradle</td><td>1992-01-10</td><td>Thriller/Suspense</td><td>R</td><td>88036683</td><td>178831137</td><td>7a8edd8f-41ce-4b56-8a81-01179c171f9d</td></tr></table>
-- ...

-- %%
select * from movie_gross
EXCEPT SELECT * FROM train_data
-- Out:
-- (173 rows affected)
-- Total execution time: 00:00:00.025
-- ...

-- %%
select movie_title,COUNT(movie_title) as [count],AVG(total_gross) as [AVG] 
from movie_gross GROUP BY movie_title


select movie_title,COUNT(movie_title) as [count] FROM movie_gross group by movie_title 

select movie_title,COUNT(movie_title) as [count] ,total_gross FROM movie_gross 
where total_gross > (select AVG(total_gross) from movie_gross) GROUP by movie_title,total_gross ORDER BY total_gross DESC
-- Out:
-- (573 rows affected)
-- (573 rows affected)
-- (168 rows affected)
-- Total execution time: 00:00:00.015
-- ...

-- %%
SELECT avg(total_gross) from movie_gross
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>(No column name)</th></tr><tr><td>64701788</td></tr></table>

-- %%
select director, COUNT(*) no_movies from director GROUP BY director ORDER by no_movies DESC

select top 1 director, COUNT(*) no_movies from director GROUP BY director ORDER by no_movies DESC

select top 1 with ties director, COUNT(*) no_movies from director GROUP BY director ORDER by no_movies DESC

select top 6 with ties director, COUNT(*) no_movies from director GROUP BY director ORDER by no_movies DESC
-- Out:
-- (29 rows affected)
-- (1 row affected)
-- (2 rows affected)
-- (13 rows affected)
-- Total execution time: 00:00:00.009
-- ...

-- %%
select  top 5 WITH ties * from movie_gross ORDER BY inflation_adjusted_gross
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>movie_title</th><th>release_date</th><th>genre</th><th>mpaa_rating</th><th>total_gross</th><th>inflation_adjusted_gross</th></tr><tr><td>The Many Adventures of Winnie the Pooh</td><td>1977-03-11</td><td>NULL</td><td>NULL</td><td>0</td><td>0</td></tr><tr><td>Amy</td><td>1981-03-20</td><td>Drama</td><td>NULL</td><td>0</td><td>0</td></tr><tr><td>Condorman</td><td>1981-08-07</td><td>Action</td><td>NULL</td><td>0</td><td>0</td></tr><tr><td>Frank McKlusky C.I.</td><td>2002-01-01</td><td>NULL</td><td>NULL</td><td>0</td><td>0</td></tr><tr><td>Zokkomon</td><td>2011-04-22</td><td>Adventure</td><td>PG</td><td>2815</td><td>2984</td></tr></table>

-- %%
SELECT * FROM movie_gross 
ORDER BY inflation_adjusted_gross 
DESC OFFSET 0 ROW FETCH NEXT 5 ROWS ONLY

SELECT * FROM movie_gross 
ORDER BY inflation_adjusted_gross 
DESC OFFSET 2 ROW FETCH NEXT 3 ROWS ONLY
-- Out:
-- (5 rows affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>movie_title</th><th>release_date</th><th>genre</th><th>mpaa_rating</th><th>total_gross</th><th>inflation_adjusted_gross</th></tr><tr><td>Snow White and the Seven Dwarfs</td><td>1937-12-21</td><td>Musical</td><td>G</td><td>184925485</td><td>5228953251</td></tr><tr><td>Pinocchio</td><td>1940-02-09</td><td>Adventure</td><td>G</td><td>84300000</td><td>2188229052</td></tr><tr><td>Fantasia</td><td>1940-11-13</td><td>Musical</td><td>G</td><td>83320000</td><td>2187090808</td></tr><tr><td>101 Dalmatians</td><td>1961-01-25</td><td>Comedy</td><td>G</td><td>153000000</td><td>1362870985</td></tr><tr><td>Lady and the Tramp</td><td>1955-06-22</td><td>Drama</td><td>G</td><td>93600000</td><td>1236035515</td></tr></table>
-- ...

-- %%
select top 5 with ties movie_title +' | '+ genre from movie_gross ORDER BY total_gross DESC

select top 5 with ties movie_title +'('+genre+')' from movie_gross ORDER BY total_gross DESC

select top 5  with ties CONCAT(movie_title,'(',release_date,')') from movie_gross ORDER BY total_gross DESC

select top 5  with ties CONCAT(movie_title,'(',yeAR(release_date),')') from movie_gross ORDER BY total_gross DESC

select top 5  with ties CONCAT(movie_title,'(',yeAR(release_date),')') from movie_gross ORDER BY total_gross DESC

SELECT top 5 with ties CONCAT(movie_title,'(',format(total_gross,'N0'),')') from movie_gross ORDER BY total_gross DESC

SELECT top 5 with ties CONCAT(movie_title,'(',format(total_gross,'#,##0 USD'),')') from movie_gross ORDER BY total_gross DESC
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- (5 rows affected)
-- (5 rows affected)
-- (5 rows affected)
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>(No column name)</th></tr><tr><td>Star Wars Ep. VII: The Force Awakens | Adventure</td></tr><tr><td>The Avengers | Action</td></tr><tr><td>Rogue One: A Star Wars Story | Adventure</td></tr><tr><td>Finding Dory | Adventure</td></tr><tr><td>Avengers: Age of Ultron | Action</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>Star Wars Ep. VII: The Force Awakens(Adventure)</td></tr><tr><td>The Avengers(Action)</td></tr><tr><td>Rogue One: A Star Wars Story(Adventure)</td></tr><tr><td>Finding Dory(Adventure)</td></tr><tr><td>Avengers: Age of Ultron(Action)</td></tr></table>
-- ...

-- %%
SELECT top 5 movie_title,UPPER(movie_title),
LOWER(movie_title),
SUBSTRING(movie_title,1,10) + '...' ,
SUBSTRING(movie_title,5,10) + '...'
from movie_gross

SELECT top 1 with ties movie_title, LEN(movie_title) as [lenght of string] from movie_gross ORDER BY [lenght of string] DESC
-- Out:
-- (5 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>movie_title</th><th>(No column name)</th><th>(No column name)</th><th>(No column name)</th><th>(No column name)</th></tr><tr><td>Snow White and the Seven Dwarfs</td><td>SNOW WHITE AND THE SEVEN DWARFS</td><td>snow white and the seven dwarfs</td><td>Snow White...</td><td> White and...</td></tr><tr><td>Pinocchio</td><td>PINOCCHIO</td><td>pinocchio</td><td>Pinocchio...</td><td>cchio...</td></tr><tr><td>Fantasia</td><td>FANTASIA</td><td>fantasia</td><td>Fantasia...</td><td>asia...</td></tr><tr><td>Song of the South</td><td>SONG OF THE SOUTH</td><td>song of the south</td><td>Song of th...</td><td> of the So...</td></tr><tr><td>Cinderella</td><td>CINDERELLA</td><td>cinderella</td><td>Cinderella...</td><td>erella...</td></tr></table>
-- ...

-- %%
select top 5 movie_title,director,CHARINDEX(' ',director) as [space],
SUBSTRING(director,1,CHARINDEX(' ',director)-1) [first_name],
SUBSTRING(director,CHARINDEX(' ',director)+1,100) [last_name],
LEFT(director,CHARINDEX(' ',director)-1)
 FROM director
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>movie_title</th><th>director</th><th>space</th><th>first_name</th><th>last_name</th><th>(No column name)</th></tr><tr><td>Snow White and the Seven Dwarfs</td><td>David Hand</td><td>6</td><td>David</td><td>Hand</td><td>David</td></tr><tr><td>Pinocchio</td><td>Ben Sharpsteen</td><td>4</td><td>Ben</td><td>Sharpsteen</td><td>Ben</td></tr><tr><td>Fantasia</td><td>full credits</td><td>5</td><td>full</td><td>credits</td><td>full</td></tr><tr><td>Dumbo</td><td>Ben Sharpsteen</td><td>4</td><td>Ben</td><td>Sharpsteen</td><td>Ben</td></tr><tr><td>Bambi</td><td>David Hand</td><td>6</td><td>David</td><td>Hand</td><td>David</td></tr></table>

-- %%
select top 5 movie_title,director,CHARINDEX(' ',director) as [space],
SUBSTRING(director,1,CHARINDEX(' ',director)-1) [first_name],
upper(SUBSTRING(director,CHARINDEX(' ',director)+1,100)) last_name,
upper(SUBSTRING(director,CHARINDEX(' ',director)+1,100)) + ' ' + LEFT(SUBSTRING(director,1,CHARINDEX(' ',director)-1),1) + '.'
 FROM director order by last_name
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>movie_title</th><th>director</th><th>space</th><th>first_name</th><th>last_name</th><th>(No column name)</th></tr><tr><td>The Lion King</td><td>Roger Allers</td><td>6</td><td>Roger</td><td>ALLERS</td><td>ALLERS R.</td></tr><tr><td>The Black Cauldron</td><td>Ted Berman</td><td>4</td><td>Ted</td><td>BERMAN</td><td>BERMAN T.</td></tr><tr><td>Tarzan</td><td>Chris Buck</td><td>6</td><td>Chris</td><td>BUCK</td><td>BUCK C.</td></tr><tr><td>Frozen</td><td>Chris Buck</td><td>6</td><td>Chris</td><td>BUCK</td><td>BUCK C.</td></tr><tr><td>The Great Mouse Detective</td><td>Ron Clements</td><td>4</td><td>Ron</td><td>CLEMENTS</td><td>CLEMENTS R.</td></tr></table>

-- %%
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>(No column name)</th></tr><tr><td>++++++++++</td></tr></table>

-- %%
select director , COUNT(*) no_movies , 
REPLICATE(NCHAR(0x2588), COUNT(*)),REPLICATE(NCHAR(0x2591), COUNT(*))
from director
GROUP BY director
HAVING COUNT(*) > 1
ORDER BY no_movies DESC
-- Out:
-- (13 rows affected)
-- Total execution time: 00:00:00.006
-- ...

-- %%
SELECT movie_title,
format(total_gross, '#,##0,,m') USD,
REPLICATE(NCHAR(0x2588),ceiling(total_gross/10e6)) bar
 from movie_gross
 where YEAR(release_date) = 2016
 ORDER BY total_gross DESC
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:00.007
-- ...

-- %%
select NCHAR(0x2591) , NCHAR(0x2592) , NCHAR(0x2593)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>(No column name)</th><th>(No column name)</th><th>(No column name)</th></tr><tr><td>░</td><td>▒</td><td>▓</td></tr></table>

-- %%
select NCHAR(0x2591) as [░ like], NCHAR(0x2592) as [▒ neutral] , NCHAR(0x2593) as [▓ ]
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>░ like</th><th>▒</th><th>▓</th></tr><tr><td>░</td><td>▒</td><td>▓</td></tr></table>

-- %%
select REPLICATE(NCHAR(0x2591),5)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>(No column name)</th></tr><tr><td>░░░░░</td></tr></table>

-- %%
SELECT * from vote3
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.003
-- <table><tr><th>menu</th><th>like</th><th>neutral</th><th>dislike</th></tr><tr><td>mocha</td><td>25</td><td>20</td><td>11</td></tr><tr><td>latte</td><td>22</td><td>12</td><td>5</td></tr><tr><td>green tea</td><td>29</td><td>5</td><td>8</td></tr><tr><td>jasmine tea</td><td>10</td><td>15</td><td>20</td></tr><tr><td>mango smoothie</td><td>20</td><td>15</td><td>4</td></tr><tr><td>kiwi smoothie</td><td>5</td><td>20</td><td>7</td></tr></table>

-- %%
SELECT menu,[like],neutral ,dislike ,
REPLICATE(nchar(0x2591),[like]) as [like],
REPLICATE(nchar(0x2592),neutral) as neutral,
REPLICATE(nchar(0x2593),dislike) as dislike
from vote3
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>menu</th><th>like</th><th>neutral</th><th>dislike</th><th>like</th><th>neutral</th><th>dislike</th></tr><tr><td>mocha</td><td>25</td><td>20</td><td>11</td><td>░░░░░░░░░░░░░░░░░░░░░░░░░</td><td>▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒</td><td>▓▓▓▓▓▓▓▓▓▓▓</td></tr><tr><td>latte</td><td>22</td><td>12</td><td>5</td><td>░░░░░░░░░░░░░░░░░░░░░░</td><td>▒▒▒▒▒▒▒▒▒▒▒▒</td><td>▓▓▓▓▓</td></tr><tr><td>green tea</td><td>29</td><td>5</td><td>8</td><td>░░░░░░░░░░░░░░░░░░░░░░░░░░░░░</td><td>▒▒▒▒▒</td><td>▓▓▓▓▓▓▓▓</td></tr><tr><td>jasmine tea</td><td>10</td><td>15</td><td>20</td><td>░░░░░░░░░░</td><td>▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒</td><td>▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓</td></tr><tr><td>mango smoothie</td><td>20</td><td>15</td><td>4</td><td>░░░░░░░░░░░░░░░░░░░░</td><td>▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒</td><td>▓▓▓▓</td></tr><tr><td>kiwi smoothie</td><td>5</td><td>20</td><td>7</td><td>░░░░░</td><td>▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒</td><td>▓▓▓▓▓▓▓</td></tr></table>

-- %%
SELECT menu,[like],neutral ,dislike ,
REPLICATE(nchar(0x2591),[like]) +
REPLICATE(nchar(0x2592),neutral) +
REPLICATE(nchar(0x2593),dislike) as [░ like ▒ neutral ▓ dislike]
from vote3
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.003
-- <table><tr><th>menu</th><th>like</th><th>neutral</th><th>dislike</th><th>░ like ▒ neutral ▓ dislike</th></tr><tr><td>mocha</td><td>25</td><td>20</td><td>11</td><td>░░░░░░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓▓▓▓▓▓▓</td></tr><tr><td>latte</td><td>22</td><td>12</td><td>5</td><td>░░░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓</td></tr><tr><td>green tea</td><td>29</td><td>5</td><td>8</td><td>░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▓▓▓▓▓▓▓▓</td></tr><tr><td>jasmine tea</td><td>10</td><td>15</td><td>20</td><td>░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓</td></tr><tr><td>mango smoothie</td><td>20</td><td>15</td><td>4</td><td>░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓</td></tr><tr><td>kiwi smoothie</td><td>5</td><td>20</td><td>7</td><td>░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓▓▓</td></tr></table>

-- %%
SELECT menu,[like],neutral ,dislike ,
REPLICATE(nchar(0x2591),[like] / [like] + neutral + dislike) +
REPLICATE(nchar(0x2592),neutral / [like] + neutral + dislike) +
REPLICATE(nchar(0x2593),dislike / [like] + neutral + dislike) as [░ like ▒ neutral ▓ dislike]
from vote3
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.005
-- ...

-- %%
select top 5 with ties MONTH(release_date),movie_title from movie_gross ORDER by total_gross

select top 5 with ties movie_title, MONTH(release_date) from movie_gross ORDER BY total_gross
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>(No column name)</th><th>movie_title</th></tr><tr><td>3</td><td>The Many Adventures of Winnie the Pooh</td></tr><tr><td>3</td><td>Amy</td></tr><tr><td>8</td><td>Condorman</td></tr><tr><td>1</td><td>Frank McKlusky C.I.</td></tr><tr><td>4</td><td>Zokkomon</td></tr></table>
-- <table><tr><th>movie_title</th><th>(No column name)</th></tr><tr><td>The Many Adventures of Winnie the Pooh</td><td>3</td></tr><tr><td>Amy</td><td>3</td></tr><tr><td>Condorman</td><td>8</td></tr><tr><td>Frank McKlusky C.I.</td><td>1</td></tr><tr><td>Zokkomon</td><td>4</td></tr></table>

-- %%
SELECT top 10 release_date,
FORMAT(release_date,'d','th') as 'd-th', 
FORMAT(release_date,'dd','th') as 'dd-th', 
FORMAT(release_date,'ddd','th') as 'ddd-th', 
FORMAT(release_date,'dddd','th') as 'dddd-th'

from movie_gross
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>release_date</th><th>d-th</th><th>dd-th</th><th>ddd-th</th><th>dddd-th</th></tr><tr><td>1937-12-21</td><td>21/12/2480</td><td>21</td><td>อ.</td><td>อังคาร</td></tr><tr><td>1940-02-09</td><td>9/2/2483</td><td>09</td><td>ศ.</td><td>ศุกร์</td></tr><tr><td>1940-11-13</td><td>13/11/2483</td><td>13</td><td>พ.</td><td>พุธ</td></tr><tr><td>1946-11-12</td><td>12/11/2489</td><td>12</td><td>อ.</td><td>อังคาร</td></tr><tr><td>1950-02-15</td><td>15/2/2493</td><td>15</td><td>พ.</td><td>พุธ</td></tr><tr><td>1954-12-23</td><td>23/12/2497</td><td>23</td><td>พฤ.</td><td>พฤหัสบดี</td></tr><tr><td>1955-06-22</td><td>22/6/2498</td><td>22</td><td>พ.</td><td>พุธ</td></tr><tr><td>1959-01-29</td><td>29/1/2502</td><td>29</td><td>พฤ.</td><td>พฤหัสบดี</td></tr><tr><td>1961-01-25</td><td>25/1/2504</td><td>25</td><td>พ.</td><td>พุธ</td></tr><tr><td>1961-03-16</td><td>16/3/2504</td><td>16</td><td>พฤ.</td><td>พฤหัสบดี</td></tr></table>

-- %%
select top 1 with ties release_date,
FORMAT(release_date,'dddd','th') as [hits day]
from movie_gross order by FORMAT(release_date,'dddd','th')
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>release_date</th><th>hits day</th></tr><tr><td>1984-09-29</td><td>เสาร์</td></tr><tr><td>1993-12-25</td><td>เสาร์</td></tr><tr><td>1995-06-10</td><td>เสาร์</td></tr><tr><td>2000-01-01</td><td>เสาร์</td></tr><tr><td>2007-09-22</td><td>เสาร์</td></tr><tr><td>2007-10-20</td><td>เสาร์</td></tr><tr><td>2014-05-10</td><td>เสาร์</td></tr></table>

-- %%
select FORMAT(release_date,'ddd','en') weekday,
COUNT(*) [number of movies]
from movie_gross GROUP BY FORMAT(release_date,'ddd','en')
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>weekday</th><th>number of movies</th></tr><tr><td>Fri</td><td>464</td></tr><tr><td>Sat</td><td>7</td></tr><tr><td>Sun</td><td>4</td></tr><tr><td>Thu</td><td>20</td></tr><tr><td>Tue</td><td>9</td></tr><tr><td>Wed</td><td>75</td></tr></table>

-- %%
select FORMAT(release_date,'ddd','en') weekday,
COUNT(*) [number of movies]
from movie_gross GROUP BY FORMAT(release_date,'ddd','en')
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>weekday</th><th>number of movies</th></tr><tr><td>Fri</td><td>464</td></tr><tr><td>Sat</td><td>7</td></tr><tr><td>Sun</td><td>4</td></tr><tr><td>Thu</td><td>20</td></tr><tr><td>Tue</td><td>9</td></tr><tr><td>Wed</td><td>75</td></tr></table>
